# %%
# %matplotlib notebook
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

# %%
data = pd.read_table('data.txt')

# %%
data.head()
# Out:
#    sepsis_label sepsis_name sepsis_subtype  glucose  Hemoglobin  capillary_ph  \
# 0             1      sepsis         severe      192         8.4           7.3
# 1             1      sepsis         severe      180         8.0           6.8
# 2             1      sepsis         severe      176         7.4           7.2
# 3             2   no_sepsis             no       86         6.2           4.7
# 4             2   no_sepsis             no       84         6.0           4.6
#
#    color_score
# 0         0.55
# 1         0.59
# 2         0.60
# 3         0.80
# 4         0.79

# %%
data.shape
# Out:
# (24, 7)

# %%
data_unique = dict(zip(data.sepsis_label.unique(),data.sepsis_name.unique()))
print(data_unique)
# Out:
# {1: 'sepsis', 2: 'no_sepsis'}

# %%
X = data[['glucose', 'Hemoglobin','capillary_ph','color_score']]
y = data['sepsis_label']

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=0)

# %%
print(X_train)
print("\n")
print(y_train)
print("\n")
print(X_test)
print("\n")
print(y_test)
# Out:
#     glucose  Hemoglobin  capillary_ph  color_score
# 13      164         7.3           7.7         0.70
# 23      170         7.6           7.9         0.88
# 16      156         7.6           7.5         0.67
# 8       178         7.1           7.8         0.92
# 6        80         5.9           4.3         0.81
# 17      168         7.5           7.6         0.73
# 4        84         6.0           4.6         0.79
# 2       176         7.4           7.2         0.60
# 5        80         5.8           4.3         0.77
# 18      162         7.5           7.1         0.83
# 9       172         7.4           7.0         0.89
# 7        76         5.8           4.0         0.81
# 19      162         7.4           7.2         0.85
# 3        86         6.2           4.7         0.80
# 0       192         8.4           7.3         0.55
# 21      156         7.4           7.4         0.84
# 15      156         7.7           7.1         0.69
# ...

# %%
from matplotlib import cm
cmap = cm.get_cmap('gnuplot')
scatter = pd.scatter_matrix(X_train , c=y_train , marker = 'o',s=40, hist_kwds= {'bins':15} , figsize=(12,12), cmap=cmap)
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:3: FutureWarning: pandas.scatter_matrix is deprecated, use pandas.plotting.scatter_matrix instead
#   This is separate from the ipykernel package so we can avoid doing imports until
# <img src="data:image/png;base64,..." width="1198.8889206485992">

# %%
from mpl_toolkits.mplot3d import Axes3D
fig = plt.figure()
ax = fig.add_subplot(111,projection = '3d')
ax.scatter(X_train['glucose'], X_train['Hemoglobin'],X_train['color_score'], c=y_train ,marker = 'o',s=100)
ax.set_xlabel('glucose')
ax.set_ylabel('Hemoglobin')
ax.set_zlabel('color_score')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="638.888905813665">

# %%
from sklearn.neighbors import KNeighborsClassifier
knn = KNeighborsClassifier(n_neighbors = 1)

# %%
knn.fit(X_train, y_train)
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=None, n_neighbors=1, p=2,
#            weights='uniform')

# %%
knn.score(X_test,y_test)
# Out:
# 0.8333333333333334

# %%
data_prediction = knn.predict([[155,6.43,9.5,1]])
data_unique[data_prediction[0]]
# Out:
# 'no_sepsis'
